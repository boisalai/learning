# %% [markdown]
# # Altair
#
# Altair is a declarative statistical visualization library for Python, based on Vega and Vega-Lite, and the source is available on GitHub.
#
# See https://altair-viz.github.io/getting_started/overview.html

# %%
# See https://altair-viz.github.io/getting_started/overview.html
# !pip install altair
# Out:
# Requirement already satisfied: altair in /Users/boisalai/opt/anaconda3/lib/python3.9/site-packages (4.2.0)
# Requirement already satisfied: toolz in /Users/boisalai/opt/anaconda3/lib/python3.9/site-packages (from altair) (0.11.2)
# Requirement already satisfied: jsonschema>=3.0 in /Users/boisalai/opt/anaconda3/lib/python3.9/site-packages (from altair) (4.4.0)
# Requirement already satisfied: numpy in /Users/boisalai/opt/anaconda3/lib/python3.9/site-packages (from altair) (1.21.5)
# Requirement already satisfied: jinja2 in /Users/boisalai/opt/anaconda3/lib/python3.9/site-packages (from altair) (2.11.3)
# Requirement already satisfied: entrypoints in /Users/boisalai/opt/anaconda3/lib/python3.9/site-packages (from altair) (0.4)
# Requirement already satisfied: pandas>=0.18 in /Users/boisalai/opt/anaconda3/lib/python3.9/site-packages (from altair) (1.4.2)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /Users/boisalai/opt/anaconda3/lib/python3.9/site-packages (from jsonschema>=3.0->altair) (0.18.0)
# Requirement already satisfied: attrs>=17.4.0 in /Users/boisalai/opt/anaconda3/lib/python3.9/site-packages (from jsonschema>=3.0->altair) (21.4.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in /Users/boisalai/opt/anaconda3/lib/python3.9/site-packages (from pandas>=0.18->altair) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/boisalai/opt/anaconda3/lib/python3.9/site-packages (from pandas>=0.18->altair) (2022.1)
# Requirement already satisfied: six>=1.5 in /Users/boisalai/opt/anaconda3/lib/python3.9/site-packages (from python-dateutil>=2.8.1->pandas>=0.18->altair) (1.16.0)
# Requirement already satisfied: MarkupSafe>=0.23 in /Users/boisalai/opt/anaconda3/lib/python3.9/site-packages (from jinja2->altair) (2.0.1)

# %%
# See https://github.com/altair-viz/vega_datasets
# !pip install vega_datasets
# Out:
# Requirement already satisfied: vega_datasets in /Users/boisalai/opt/anaconda3/lib/python3.9/site-packages (0.9.0)
# Requirement already satisfied: pandas in /Users/boisalai/opt/anaconda3/lib/python3.9/site-packages (from vega_datasets) (1.4.2)
# Requirement already satisfied: python-dateutil>=2.8.1 in /Users/boisalai/opt/anaconda3/lib/python3.9/site-packages (from pandas->vega_datasets) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/boisalai/opt/anaconda3/lib/python3.9/site-packages (from pandas->vega_datasets) (2022.1)
# Requirement already satisfied: numpy>=1.18.5 in /Users/boisalai/opt/anaconda3/lib/python3.9/site-packages (from pandas->vega_datasets) (1.21.5)
# Requirement already satisfied: six>=1.5 in /Users/boisalai/opt/anaconda3/lib/python3.9/site-packages (from python-dateutil>=2.8.1->pandas->vega_datasets) (1.16.0)

# %%
import altair as alt

# load a simple dataset as a pandas DataFrame
from vega_datasets import data
cars = data.cars()

alt.Chart(cars).mark_point().encode(
    x='Horsepower',
    y='Miles_per_Gallon',
    color='Origin',
).interactive()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /Users/boisalai/Documents/GitHub/learning/python/visualization/altair.ipynb Cellule 4 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/Users/boisalai/Documents/GitHub/learning/python/visualization/altair.ipynb#ch0000003?line=0'>1</a> import altair as alt
#       <a href='vscode-notebook-cell:/Users/boisalai/Documents/GitHub/learning/python/visualization/altair.ipynb#ch0000003?line=2'>3</a> # load a simple dataset as a pandas DataFrame
#       <a href='vscode-notebook-cell:/Users/boisalai/Documents/GitHub/learning/python/visualization/altair.ipynb#ch0000003?line=3'>4</a> from vega_datasets import data
#
# ModuleNotFoundError: No module named 'altair'
