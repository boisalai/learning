# %% [markdown]
# To use the HuggingFace [`transformers` Python library](https://huggingface.co/transformers/installation.html), we first need to install it with `pip`.

# %%
# !pip install transformers

# %%
# See https://twitter.com/mervenoyann/status/1518563617209212932?s=20&t=XmuU1mFDk8u6qdmTNWkcvA
from transformers import pipeline

context = "Adventurer is approached by a mysterious stranger in the tavern for a new quest. He asks to hear if he would be able to help to locate an ancient relic."
question = "What is the purpose of the quest?"

QA_model = pipeline("question-answering")

answer = QA_model(question = question, context = context)

print(answer)

# %% [markdown]
# Check out the available pipelines here 👉🏼 https://huggingface.co/docs/transformers/main_classes/pipelines we have them on various domains and not only NLP!
